# %% [markdown]
# # Challenge Exercise
# Create a neural network that is capable of finding the volume of a cylinder given the radius of its base (r) and its height (h). Assume that the radius and height of the cylinder are both in the range 0.5 to 2.0. Simulate the necessary training dataset.

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import random
from math import pi
import shutil

print(tf.__version__)
# Out:
# 1.8.0

# %% [markdown]
# The training dataset will be randomly generated. This should be a generator, but to keep it simple i'll generate it directly on RAM. I alsowant to learn how to work with panda dataframes.

# %%
COLUMNS=['radius', 'height', 'volume']

def generate_dataset(min_value, max_value, dataset_lenght):
  dataset = []
  for i in range(dataset_lenght):
    radius = random.uniform(min_value, max_value)
    height = random.uniform(min_value, max_value)
    volume = pi * radius**2 * height
    
    dataset.append((radius, height, volume))
  return dataset
    

df_train = pd.DataFrame(generate_dataset(0.5, 2.0, 100000), columns=COLUMNS)
df_valid = pd.DataFrame(generate_dataset(0.5, 2.0, 20000), columns=COLUMNS)

train.head()
# Out:
#      radius    height    volume
# 0  1.046283  1.189658  4.091386
# 1  0.769270  0.568194  1.056340
# 2  1.515097  0.756115  5.452790
# 3  1.010015  1.551065  4.970904
# 4  0.629675  1.844631  2.297692

# %%
LABEL=COLUMNS[2]
def make_input_fn(df, num_epochs):
  return tf.estimator.inputs.pandas_input_fn(
    x = df,
    y = df[LABEL],
    batch_size = 128,
    num_epochs = num_epochs,
    shuffle = True,
    queue_capacity = 1000,
    num_threads = 1
  )

def make_prediction_input_fn(df, num_epochs):
  return tf.estimator.inputs.pandas_input_fn(
    x = df,
    y = None,
    shuffle = False
  )

FEATURES=COLUMNS[0:2]
def make_feature_cols():
  input_columns = [tf.feature_column.numeric_column(k) for k in FEATURES]
  return input_columns

# %%
def print_rmse(model, name, df):
  metrics = model.evaluate(input_fn = make_input_fn(df, 1))
  print('RMSE on {} dataset = {}'.format(name, np.sqrt(metrics['average_loss'])))

# %%
tf.logging.set_verbosity(tf.logging.INFO)

OUTDIR = 'taxi_trained'
shutil.rmtree(OUTDIR, ignore_errors = True) # start fresh each time

model = tf.estimator.DNNRegressor(hidden_units = [32, 8, 2],
      feature_columns = make_feature_cols(), model_dir = OUTDIR)

model.train(input_fn = make_input_fn(df_train, num_epochs = 10));
print_rmse(model, 'validation', df_valid)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_task_type': 'worker', '_train_distribute': None, '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fb188ccec10>, '_evaluation_master': '', '_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_num_ps_replicas': 0, '_tf_random_seed': None, '_master': '', '_num_worker_replicas': 1, '_task_id': 0, '_log_step_count_steps': 100, '_model_dir': 'taxi_trained', '_global_id_in_cluster': 0, '_save_summary_steps': 100}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into taxi_trained/model.ckpt.
# INFO:tensorflow:loss = 9901.495, step = 1
# INFO:tensorflow:global_step/sec: 347.606
# INFO:tensorflow:loss = 202.81647, step = 101 (0.293 sec)
# INFO:tensorflow:global_step/sec: 428.942
# INFO:tensorflow:loss = 42.421997, step = 201 (0.232 sec)
# INFO:tensorflow:global_step/sec: 324.28
# INFO:tensorflow:loss = 34.461327, step = 301 (0.309 sec)
# INFO:tensorflow:global_step/sec: 438.882
# INFO:tensorflow:loss = 14.558987, step = 401 (0.228 sec)
# INFO:tensorflow:global_step/sec: 432.547
# INFO:tensorflow:loss = 11.716814, step = 501 (0.231 sec)
# INFO:tensorflow:global_step/sec: 392.875
# INFO:tensorflow:loss = 16.37606, step = 601 (0.255 sec)
# INFO:tensorflow:global_step/sec: 320.313
# INFO:tensorflow:loss = 14.49597, step = 701 (0.313 sec)
# INFO:tensorflow:global_step/sec: 419.694
# INFO:tensorflow:loss = 10.112172, step = 801 (0.238 sec)
# INFO:tensorflow:global_step/sec: 432.15
# INFO:tensorflow:loss = 8.420782, step = 901 (0.231 sec)
# INFO:tensorflow:global_step/sec: 428.971
# INFO:tensorflow:loss = 7.6457567, step = 1001 (0.233 sec)
# INFO:tensorflow:global_step/sec: 388.849
# INFO:tensorflow:loss = 12.537395, step = 1101 (0.258 sec)
# INFO:tensorflow:global_step/sec: 422.983
# INFO:tensorflow:loss = 6.225321, step = 1201 (0.236 sec)
# INFO:tensorflow:global_step/sec: 440.989
# INFO:tensorflow:loss = 8.678864, step = 1301 (0.227 sec)
# INFO:tensorflow:global_step/sec: 448.081
# INFO:tensorflow:loss = 6.5751104, step = 1401 (0.223 sec)
# INFO:tensorflow:global_step/sec: 384.329
# INFO:tensorflow:loss = 6.3068094, step = 1501 (0.260 sec)
# INFO:tensorflow:global_step/sec: 425.261
# INFO:tensorflow:loss = 5.05768, step = 1601 (0.235 sec)
# INFO:tensorflow:global_step/sec: 422.163
# INFO:tensorflow:loss = 5.357916, step = 1701 (0.237 sec)
# INFO:tensorflow:global_step/sec: 420.746
# INFO:tensorflow:loss = 6.0379353, step = 1801 (0.237 sec)
# INFO:tensorflow:global_step/sec: 446.429
# INFO:tensorflow:loss = 4.481122, step = 1901 (0.224 sec)
# INFO:tensorflow:global_step/sec: 308.935
# INFO:tensorflow:loss = 7.7418737, step = 2001 (0.324 sec)
# INFO:tensorflow:global_step/sec: 425.639
# INFO:tensorflow:loss = 6.4702177, step = 2101 (0.235 sec)
# INFO:tensorflow:global_step/sec: 401.415
# INFO:tensorflow:loss = 5.3197412, step = 2201 (0.249 sec)
# INFO:tensorflow:global_step/sec: 388.83
# INFO:tensorflow:loss = 5.9588003, step = 2301 (0.257 sec)
# INFO:tensorflow:global_step/sec: 412.102
# INFO:tensorflow:loss = 6.487443, step = 2401 (0.242 sec)
# INFO:tensorflow:global_step/sec: 449.311
# INFO:tensorflow:loss = 5.2060785, step = 2501 (0.223 sec)
# INFO:tensorflow:global_step/sec: 429.873
# INFO:tensorflow:loss = 5.164718, step = 2601 (0.233 sec)
# INFO:tensorflow:global_step/sec: 438.471
# INFO:tensorflow:loss = 5.8476133, step = 2701 (0.228 sec)
# INFO:tensorflow:global_step/sec: 331.025
# INFO:tensorflow:loss = 4.721465, step = 2801 (0.302 sec)
# INFO:tensorflow:global_step/sec: 435.265
# INFO:tensorflow:loss = 4.56987, step = 2901 (0.229 sec)
# INFO:tensorflow:global_step/sec: 442.323
# INFO:tensorflow:loss = 3.6811333, step = 3001 (0.226 sec)
# INFO:tensorflow:global_step/sec: 408.834
# INFO:tensorflow:loss = 3.6570308, step = 3101 (0.244 sec)
# INFO:tensorflow:global_step/sec: 381.676
# INFO:tensorflow:loss = 3.9493992, step = 3201 (0.272 sec)
# INFO:tensorflow:global_step/sec: 422.651
# INFO:tensorflow:loss = 4.1990714, step = 3301 (0.227 sec)
# INFO:tensorflow:global_step/sec: 428.844
# INFO:tensorflow:loss = 4.625292, step = 3401 (0.233 sec)
# INFO:tensorflow:global_step/sec: 449.315
# INFO:tensorflow:loss = 3.90907, step = 3501 (0.222 sec)
# INFO:tensorflow:global_step/sec: 353.192
# INFO:tensorflow:loss = 4.1152697, step = 3601 (0.283 sec)
# INFO:tensorflow:global_step/sec: 447.165
# INFO:tensorflow:loss = 5.5840654, step = 3701 (0.223 sec)
# INFO:tensorflow:global_step/sec: 436.826
# INFO:tensorflow:loss = 3.7857318, step = 3801 (0.229 sec)
# INFO:tensorflow:global_step/sec: 447.644
# INFO:tensorflow:loss = 3.777001, step = 3901 (0.224 sec)
# INFO:tensorflow:global_step/sec: 297.555
# INFO:tensorflow:loss = 4.14966, step = 4001 (0.336 sec)
# INFO:tensorflow:global_step/sec: 444.002
# INFO:tensorflow:loss = 3.9982867, step = 4101 (0.226 sec)
# INFO:tensorflow:global_step/sec: 443.115
# INFO:tensorflow:loss = 3.1635628, step = 4201 (0.225 sec)
# INFO:tensorflow:global_step/sec: 442.666
# INFO:tensorflow:loss = 4.2772627, step = 4301 (0.226 sec)
# INFO:tensorflow:global_step/sec: 317.5
# INFO:tensorflow:loss = 3.0994902, step = 4401 (0.315 sec)
# INFO:tensorflow:global_step/sec: 420.456
# INFO:tensorflow:loss = 2.8534856, step = 4501 (0.238 sec)
# INFO:tensorflow:global_step/sec: 442.402
# INFO:tensorflow:loss = 2.7203012, step = 4601 (0.226 sec)
# INFO:tensorflow:global_step/sec: 435.963
# INFO:tensorflow:loss = 3.2773118, step = 4701 (0.229 sec)
# INFO:tensorflow:global_step/sec: 331.131
# INFO:tensorflow:loss = 3.227553, step = 4801 (0.307 sec)
# INFO:tensorflow:global_step/sec: 432.565
# INFO:tensorflow:loss = 2.8903375, step = 4901 (0.227 sec)
# INFO:tensorflow:global_step/sec: 430.882
# INFO:tensorflow:loss = 2.5530071, step = 5001 (0.232 sec)
# INFO:tensorflow:global_step/sec: 440.647
# INFO:tensorflow:loss = 3.3925853, step = 5101 (0.227 sec)
# INFO:tensorflow:global_step/sec: 324.544
# INFO:tensorflow:loss = 3.5441298, step = 5201 (0.308 sec)
# INFO:tensorflow:global_step/sec: 452.958
# INFO:tensorflow:loss = 2.8372188, step = 5301 (0.221 sec)
# INFO:tensorflow:global_step/sec: 432.919
# INFO:tensorflow:loss = 3.698155, step = 5401 (0.231 sec)
# INFO:tensorflow:global_step/sec: 449.23
# INFO:tensorflow:loss = 2.4298582, step = 5501 (0.223 sec)
# INFO:tensorflow:global_step/sec: 357.952
# INFO:tensorflow:loss = 3.136056, step = 5601 (0.280 sec)
# INFO:tensorflow:global_step/sec: 392.747
# INFO:tensorflow:loss = 2.8504202, step = 5701 (0.254 sec)
# INFO:tensorflow:global_step/sec: 444.316
# INFO:tensorflow:loss = 3.2475808, step = 5801 (0.225 sec)
# INFO:tensorflow:global_step/sec: 446.442
# INFO:tensorflow:loss = 2.6527197, step = 5901 (0.224 sec)
# INFO:tensorflow:global_step/sec: 334.388
# INFO:tensorflow:loss = 3.1241655, step = 6001 (0.299 sec)
# INFO:tensorflow:global_step/sec: 428.857
# INFO:tensorflow:loss = 2.718584, step = 6101 (0.233 sec)
# INFO:tensorflow:global_step/sec: 411.936
# INFO:tensorflow:loss = 2.8604903, step = 6201 (0.243 sec)
# INFO:tensorflow:global_step/sec: 416.398
# INFO:tensorflow:loss = 2.841598, step = 6301 (0.240 sec)
# INFO:tensorflow:global_step/sec: 388.002
# INFO:tensorflow:loss = 3.0492558, step = 6401 (0.258 sec)
# INFO:tensorflow:global_step/sec: 447.377
# INFO:tensorflow:loss = 3.6979265, step = 6501 (0.225 sec)
# INFO:tensorflow:global_step/sec: 428.517
# INFO:tensorflow:loss = 2.2413542, step = 6601 (0.232 sec)
# INFO:tensorflow:global_step/sec: 452.043
# INFO:tensorflow:loss = 2.9100423, step = 6701 (0.221 sec)
# INFO:tensorflow:global_step/sec: 330.084
# INFO:tensorflow:loss = 2.4917567, step = 6801 (0.306 sec)
# INFO:tensorflow:global_step/sec: 379.907
# INFO:tensorflow:loss = 3.1184359, step = 6901 (0.260 sec)
# INFO:tensorflow:global_step/sec: 452.509
# INFO:tensorflow:loss = 2.17385, step = 7001 (0.221 sec)
# INFO:tensorflow:global_step/sec: 443.068
# INFO:tensorflow:loss = 2.6053195, step = 7101 (0.226 sec)
# INFO:tensorflow:global_step/sec: 331.011
# INFO:tensorflow:loss = 3.3137972, step = 7201 (0.302 sec)
# INFO:tensorflow:global_step/sec: 428.128
# INFO:tensorflow:loss = 3.0122797, step = 7301 (0.234 sec)
# INFO:tensorflow:global_step/sec: 422.144
# INFO:tensorflow:loss = 2.4142647, step = 7401 (0.237 sec)
# INFO:tensorflow:global_step/sec: 388.801
# INFO:tensorflow:loss = 2.5640826, step = 7501 (0.257 sec)
# INFO:tensorflow:global_step/sec: 322.388
# INFO:tensorflow:loss = 2.1890771, step = 7601 (0.310 sec)
# INFO:tensorflow:global_step/sec: 408.433
# INFO:tensorflow:loss = 2.726472, step = 7701 (0.245 sec)
# INFO:tensorflow:global_step/sec: 425.414
# INFO:tensorflow:loss = 2.2686625, step = 7801 (0.235 sec)
# INFO:tensorflow:Saving checkpoints for 7813 into taxi_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.0253594.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-22-11:57:41
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from taxi_trained/model.ckpt-7813
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-22-11:57:41
# INFO:tensorflow:Saving dict for global step 7813: average_loss = 0.019667784, global_step = 7813, loss = 2.5054502
# RMSE on validation dataset = 0.140241876245

# %%
pcount=5
predictions = model.predict(input_fn = make_prediction_input_fn(df_valid[:pcount], 1))
print df_valid[0:pcount]
for i in xrange(pcount):
  print(predictions.next())
# Out:
#      radius    height     volume
# 0  1.699392  1.216494  11.036893
# 1  1.205358  0.734145   3.350922
# 2  1.853363  0.869212   9.379861
# 3  1.178952  0.771037   3.366800
# 4  1.843925  1.956811  20.901870
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from taxi_trained/model.ckpt-7813
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# {'predictions': array([11.270093], dtype=float32)}
# {'predictions': array([3.2542899], dtype=float32)}
# {'predictions': array([9.295976], dtype=float32)}
# {'predictions': array([3.2169807], dtype=float32)}
# {'predictions': array([20.876633], dtype=float32)}
