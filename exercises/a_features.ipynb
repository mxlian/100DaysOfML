# %% [markdown]
# # Trying out features

# %% [markdown]
# **Learning Objectives:**
#   * Improve the accuracy of a model by adding new features with the appropriate representation

# %% [markdown]
# The data is based on 1990 census data from California. This data is at the city block level, so these features reflect the total number of rooms in that block, or the total number of people who live on that block, respectively.

# %% [markdown]
# ## Set Up
# In this first cell, we'll load the necessary libraries.

# %%
import math
import shutil
import numpy as np
import pandas as pd
import tensorflow as tf

print(tf.__version__)
tf.logging.set_verbosity(tf.logging.INFO)
pd.options.display.max_rows = 10
pd.options.display.float_format = '{:.1f}'.format
# Out:
# /usr/local/envs/py2env/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# 1.8.0

# %% [markdown]
# Next, we'll load our data set.

# %%
df = pd.read_csv("https://storage.googleapis.com/ml_universities/california_housing_train.csv", sep=",")

# %%
df.head()
df.describe()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# count    17000.0   17000.0             17000.0      17000.0         17000.0
# mean      -119.6      35.6                28.6       2643.7           539.4
# std          2.0       2.1                12.6       2179.9           421.5
# min       -124.3      32.5                 1.0          2.0             1.0
# 25%       -121.8      33.9                18.0       1462.0           297.0
# 50%       -118.5      34.2                29.0       2127.0           434.0
# 75%       -118.0      37.7                37.0       3151.2           648.2
# max       -114.3      42.0                52.0      37937.0          6445.0
#
#        population  households  median_income  median_house_value
# count     17000.0     17000.0        17000.0             17000.0
# mean       1429.6       501.2            3.9            207300.9
# std        1147.9       384.5            1.9            115983.8
# min           3.0         1.0            0.5             14999.0
# 25%         790.0       282.0            2.6            119400.0
# 50%        1167.0       409.0            3.5            180400.0
# 75%        1721.0       605.2            4.8            265000.0
# max       35682.0      6082.0           15.0            500001.0

# %% [markdown]
# ## Examine and split the data
#
# It's a good idea to get to know your data a little bit before you work with it.
#
# We'll print out a quick summary of a few useful statistics on each column.
#
# This will include things like mean, standard deviation, max, min, and various quantiles.

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -114.3      34.2                15.0       5612.0          1283.0
# 1     -114.5      34.4                19.0       7650.0          1901.0
# 2     -114.6      33.7                17.0        720.0           174.0
# 3     -114.6      33.6                14.0       1501.0           337.0
# 4     -114.6      33.6                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0            1.5             66900.0
# 1      1129.0       463.0            1.8             80100.0
# 2       333.0       117.0            1.7             85700.0
# 3       515.0       226.0            3.2             73400.0
# 4       624.0       262.0            1.9             65500.0

# %%
df.describe()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# count    17000.0   17000.0             17000.0      17000.0         17000.0
# mean      -119.6      35.6                28.6       2643.7           539.4
# std          2.0       2.1                12.6       2179.9           421.5
# min       -124.3      32.5                 1.0          2.0             1.0
# 25%       -121.8      33.9                18.0       1462.0           297.0
# 50%       -118.5      34.2                29.0       2127.0           434.0
# 75%       -118.0      37.7                37.0       3151.2           648.2
# max       -114.3      42.0                52.0      37937.0          6445.0
#
#        population  households  median_income  median_house_value
# count     17000.0     17000.0        17000.0             17000.0
# mean       1429.6       501.2            3.9            207300.9
# std        1147.9       384.5            1.9            115983.8
# min           3.0         1.0            0.5             14999.0
# 25%         790.0       282.0            2.6            119400.0
# 50%        1167.0       409.0            3.5            180400.0
# 75%        1721.0       605.2            4.8            265000.0
# max       35682.0      6082.0           15.0            500001.0

# %% [markdown]
# Now, split the data into two parts -- training and evaluation.

# %%
np.random.seed(seed=1) #makes result reproducible
print (np.random.rand(10) < 0.3)
msk = np.random.rand(len(df)) < 0.8
traindf = df[msk]
evaldf = df[~msk]
# Out:
# [False False  True False  True  True  True False False False]

# %% [markdown]
# ## Training and Evaluation
#
# In this exercise, we'll be trying to predict **median_house_value** It will be our label (sometimes also called a target).
#
# We'll modify the feature_cols and input function to represent the features you want to use.
#
# We divide **total_rooms** by **households** to get **avg_rooms_per_house** which we excect to positively correlate with **median_house_value**.
#
# We also divide **population** by **total_rooms** to get **avg_persons_per_room** which we expect to negatively correlate with **median_house_value**.

# %%
print(df.head())
def add_more_features(df):
  df['avg_rooms_per_house'] = df['total_rooms'] / df['households'] #expect positive correlation
  df['avg_persons_per_room'] = df['population'] / df['total_rooms'] #expect negative correlation
  return df
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -114.3      34.2                15.0       5612.0          1283.0
# 1     -114.5      34.4                19.0       7650.0          1901.0
# 2     -114.6      33.7                17.0        720.0           174.0
# 3     -114.6      33.6                14.0       1501.0           337.0
# 4     -114.6      33.6                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0            1.5             66900.0
# 1      1129.0       463.0            1.8             80100.0
# 2       333.0       117.0            1.7             85700.0
# 3       515.0       226.0            3.2             73400.0
# 4       624.0       262.0            1.9             65500.0

# %%
# Create pandas input function
def make_input_fn(df, num_epochs):
  return tf.estimator.inputs.pandas_input_fn(
    x = add_more_features(df),
    y = df['median_house_value'] / 100000, # will talk about why later in the course
    batch_size = 128,
    num_epochs = num_epochs,
    shuffle = True,
    queue_capacity = 1000,
    num_threads = 1
  )

# %%
# Define your feature columns
def create_feature_cols():
  return [
    tf.feature_column.numeric_column('housing_median_age'),
    tf.feature_column.bucketized_column(tf.feature_column.numeric_column('latitude'), boundaries = np.arange(32.0, 42, 1).tolist()),
    tf.feature_column.numeric_column('avg_rooms_per_house'),
    tf.feature_column.numeric_column('avg_persons_per_room'),
    tf.feature_column.numeric_column('median_income')
  ]

# %%
# Create estimator train and evaluate function
def train_and_evaluate(output_dir, num_train_steps):
  estimator = tf.estimator.LinearRegressor(model_dir = output_dir, feature_columns = create_feature_cols())
  train_spec = tf.estimator.TrainSpec(input_fn = make_input_fn(traindf, None), 
                                      max_steps = num_train_steps)
  eval_spec = tf.estimator.EvalSpec(input_fn = make_input_fn(evaldf, 1), 
                                    steps = None, 
                                    start_delay_secs = 1, # start evaluating after N seconds, 
                                    throttle_secs = 5)  # evaluate every N seconds
  tf.estimator.train_and_evaluate(estimator, train_spec, eval_spec)

# %%
# Launch tensorboard
from google.datalab.ml import TensorBoard

OUTDIR = './trained_model'
TensorBoard().start(OUTDIR)
# Out:
# <p>TensorBoard was started successfully with pid 8963. Click <a href="/_proxy/50275/" target="_blank">here</a> to access it.</p>
# 8963

# %%
# Run the model
shutil.rmtree(OUTDIR, ignore_errors = True)
train_and_evaluate(OUTDIR, 5000)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_task_type': 'worker', '_train_distribute': None, '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7ff7831f7690>, '_evaluation_master': '', '_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_num_ps_replicas': 0, '_tf_random_seed': None, '_master': '', '_num_worker_replicas': 1, '_task_id': 0, '_log_step_count_steps': 100, '_model_dir': './trained_model', '_global_id_in_cluster': 0, '_save_summary_steps': 100}
# /usr/local/envs/py2env/lib/python2.7/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /usr/local/envs/py2env/lib/python2.7/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after 5 secs (eval_spec.throttle_secs) or training is finished.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into ./trained_model/model.ckpt.
# INFO:tensorflow:loss = 875.0117, step = 1
# INFO:tensorflow:global_step/sec: 114.696
# INFO:tensorflow:loss = 49.125675, step = 101 (0.878 sec)
# INFO:tensorflow:global_step/sec: 219.184
# INFO:tensorflow:loss = 81.45473, step = 201 (0.452 sec)
# INFO:tensorflow:global_step/sec: 203.708
# INFO:tensorflow:loss = 68.04448, step = 301 (0.491 sec)
# INFO:tensorflow:global_step/sec: 225.655
# INFO:tensorflow:loss = 80.255554, step = 401 (0.443 sec)
# INFO:tensorflow:global_step/sec: 199.743
# INFO:tensorflow:loss = 69.3015, step = 501 (0.501 sec)
# INFO:tensorflow:global_step/sec: 196.506
# INFO:tensorflow:loss = 62.609253, step = 601 (0.509 sec)
# INFO:tensorflow:global_step/sec: 180.005
# INFO:tensorflow:loss = 67.02613, step = 701 (0.557 sec)
# INFO:tensorflow:Saving checkpoints for 778 into ./trained_model/model.ckpt.
# INFO:tensorflow:Loss for final step: 124.65892.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-08-17:45:29
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_model/model.ckpt-778
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-08-17:45:29
# INFO:tensorflow:Saving dict for global step 778: average_loss = 0.73803616, global_step = 778, loss = 92.63721
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_model/model.ckpt-778
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 779 into ./trained_model/model.ckpt.
# INFO:tensorflow:loss = 124.38014, step = 779
# INFO:tensorflow:global_step/sec: 107.26
# INFO:tensorflow:loss = 100.82596, step = 879 (0.938 sec)
# INFO:tensorflow:global_step/sec: 206.551
# INFO:tensorflow:loss = 74.05095, step = 979 (0.482 sec)
# INFO:tensorflow:global_step/sec: 190.119
# INFO:tensorflow:loss = 62.99116, step = 1079 (0.525 sec)
# INFO:tensorflow:global_step/sec: 206.543
# INFO:tensorflow:loss = 58.728756, step = 1179 (0.484 sec)
# INFO:tensorflow:global_step/sec: 181.308
# INFO:tensorflow:loss = 60.381504, step = 1279 (0.551 sec)
# INFO:tensorflow:global_step/sec: 205.899
# INFO:tensorflow:loss = 64.174515, step = 1379 (0.486 sec)
# INFO:tensorflow:global_step/sec: 179.469
# INFO:tensorflow:loss = 53.344414, step = 1479 (0.558 sec)
# INFO:tensorflow:Saving checkpoints for 1489 into ./trained_model/model.ckpt.
# INFO:tensorflow:Loss for final step: 65.060684.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-08-17:45:36
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_model/model.ckpt-1489
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-08-17:45:36
# INFO:tensorflow:Saving dict for global step 1489: average_loss = 0.659518, global_step = 1489, loss = 82.78172
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_model/model.ckpt-1489
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1490 into ./trained_model/model.ckpt.
# INFO:tensorflow:loss = 182.18515, step = 1490
# INFO:tensorflow:global_step/sec: 112.742
# INFO:tensorflow:loss = 39.783714, step = 1590 (0.891 sec)
# INFO:tensorflow:global_step/sec: 177.042
# INFO:tensorflow:loss = 73.12114, step = 1690 (0.563 sec)
# INFO:tensorflow:global_step/sec: 206.602
# INFO:tensorflow:loss = 76.24446, step = 1790 (0.484 sec)
# INFO:tensorflow:global_step/sec: 188.577
# INFO:tensorflow:loss = 60.49506, step = 1890 (0.531 sec)
# INFO:tensorflow:global_step/sec: 207.471
# INFO:tensorflow:loss = 63.01725, step = 1990 (0.482 sec)
# INFO:tensorflow:global_step/sec: 189.392
# INFO:tensorflow:loss = 74.82643, step = 2090 (0.528 sec)
# INFO:tensorflow:global_step/sec: 201.805
# INFO:tensorflow:loss = 91.83838, step = 2190 (0.495 sec)
# INFO:tensorflow:Saving checkpoints for 2192 into ./trained_model/model.ckpt.
# INFO:tensorflow:Loss for final step: 98.16417.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-08-17:45:42
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_model/model.ckpt-2192
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-08-17:45:42
# INFO:tensorflow:Saving dict for global step 2192: average_loss = 0.6051667, global_step = 2192, loss = 75.959625
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_model/model.ckpt-2192
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 2193 into ./trained_model/model.ckpt.
# INFO:tensorflow:loss = 61.001358, step = 2193
# INFO:tensorflow:global_step/sec: 122.262
# INFO:tensorflow:loss = 49.588093, step = 2293 (0.823 sec)
# INFO:tensorflow:global_step/sec: 229.396
# INFO:tensorflow:loss = 81.18344, step = 2393 (0.432 sec)
# INFO:tensorflow:global_step/sec: 212.452
# INFO:tensorflow:loss = 89.49426, step = 2493 (0.471 sec)
# INFO:tensorflow:global_step/sec: 222.261
# INFO:tensorflow:loss = 68.17815, step = 2593 (0.450 sec)
# INFO:tensorflow:global_step/sec: 224.576
# INFO:tensorflow:loss = 72.13894, step = 2693 (0.445 sec)
# INFO:tensorflow:global_step/sec: 210.238
# INFO:tensorflow:loss = 96.41317, step = 2793 (0.476 sec)
# INFO:tensorflow:global_step/sec: 230.312
# INFO:tensorflow:loss = 60.589382, step = 2893 (0.434 sec)
# INFO:tensorflow:Saving checkpoints for 2981 into ./trained_model/model.ckpt.
# INFO:tensorflow:Loss for final step: 52.511986.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-08-17:45:48
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_model/model.ckpt-2981
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-08-17:45:49
# INFO:tensorflow:Saving dict for global step 2981: average_loss = 0.6139872, global_step = 2981, loss = 77.066765
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_model/model.ckpt-2981
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 2982 into ./trained_model/model.ckpt.
# INFO:tensorflow:loss = 50.1063, step = 2982
# INFO:tensorflow:global_step/sec: 117.085
# INFO:tensorflow:loss = 69.14766, step = 3082 (0.862 sec)
# INFO:tensorflow:global_step/sec: 230.912
# INFO:tensorflow:loss = 102.22893, step = 3182 (0.429 sec)
# INFO:tensorflow:global_step/sec: 183.343
# INFO:tensorflow:loss = 93.659454, step = 3282 (0.544 sec)
# INFO:tensorflow:global_step/sec: 249.042
# INFO:tensorflow:loss = 78.705734, step = 3382 (0.402 sec)
# INFO:tensorflow:global_step/sec: 197.234
# INFO:tensorflow:loss = 57.399967, step = 3482 (0.506 sec)
# INFO:tensorflow:global_step/sec: 255.738
# INFO:tensorflow:loss = 70.882965, step = 3582 (0.391 sec)
# INFO:tensorflow:global_step/sec: 257.701
# INFO:tensorflow:loss = 68.158615, step = 3682 (0.388 sec)
# INFO:tensorflow:global_step/sec: 208.555
# INFO:tensorflow:loss = 95.08941, step = 3782 (0.480 sec)
# INFO:tensorflow:Saving checkpoints for 3791 into ./trained_model/model.ckpt.
# INFO:tensorflow:Loss for final step: 63.26036.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-08-17:45:55
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_model/model.ckpt-3791
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-08-17:45:55
# INFO:tensorflow:Saving dict for global step 3791: average_loss = 0.6498433, global_step = 3791, loss = 81.56737
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_model/model.ckpt-3791
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 3792 into ./trained_model/model.ckpt.
# INFO:tensorflow:loss = 120.62895, step = 3792
# INFO:tensorflow:global_step/sec: 115.807
# INFO:tensorflow:loss = 108.39645, step = 3892 (0.870 sec)
# INFO:tensorflow:global_step/sec: 230.89
# INFO:tensorflow:loss = 86.37662, step = 3992 (0.430 sec)
# INFO:tensorflow:global_step/sec: 254.446
# INFO:tensorflow:loss = 55.589283, step = 4092 (0.393 sec)
# INFO:tensorflow:global_step/sec: 232.033
# INFO:tensorflow:loss = 33.631924, step = 4192 (0.431 sec)
# INFO:tensorflow:global_step/sec: 188.009
# INFO:tensorflow:loss = 88.344925, step = 4292 (0.532 sec)
# INFO:tensorflow:global_step/sec: 233.553
# INFO:tensorflow:loss = 77.61087, step = 4392 (0.428 sec)
# INFO:tensorflow:global_step/sec: 212.867
# INFO:tensorflow:loss = 54.85562, step = 4492 (0.469 sec)
# INFO:tensorflow:global_step/sec: 248.595
# INFO:tensorflow:loss = 116.59086, step = 4592 (0.403 sec)
# INFO:tensorflow:Saving checkpoints for 4595 into ./trained_model/model.ckpt.
# INFO:tensorflow:Loss for final step: 78.28701.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-08-17:46:01
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_model/model.ckpt-4595
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-08-17:46:01
# INFO:tensorflow:Saving dict for global step 4595: average_loss = 0.61408263, global_step = 4595, loss = 77.07874
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_model/model.ckpt-4595
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 4596 into ./trained_model/model.ckpt.
# INFO:tensorflow:loss = 59.263294, step = 4596
# INFO:tensorflow:global_step/sec: 133.745
# INFO:tensorflow:loss = 58.562363, step = 4696 (0.753 sec)
# INFO:tensorflow:global_step/sec: 204.162
# INFO:tensorflow:loss = 80.99192, step = 4796 (0.487 sec)
# INFO:tensorflow:global_step/sec: 242.994
# INFO:tensorflow:loss = 62.304474, step = 4896 (0.411 sec)
# INFO:tensorflow:global_step/sec: 224.01
# INFO:tensorflow:loss = 63.35012, step = 4996 (0.447 sec)
# INFO:tensorflow:Saving checkpoints for 5000 into ./trained_model/model.ckpt.
# INFO:tensorflow:Loss for final step: 69.269356.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-08-17:46:05
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_model/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-08-17:46:06
# INFO:tensorflow:Saving dict for global step 5000: average_loss = 0.60636646, global_step = 5000, loss = 76.110214
